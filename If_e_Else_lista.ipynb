# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianaBatistadoAmarante/JulianaBatistadoAmarante/blob/main/If_e_Else_lista.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios sobre If e Else
#
# Nesse notebook vamos resolver diversos exercícios que tem como objetivo principal mostrar o funcionamento do If e Else. Aqui não vamos utilizar nenhum conceito mais avançado de programação e você poderá resolver todos eles do seu jeito.
#
# Mas como assim do meu jeito?
#
# É verdade, cada exercício pode ser resolvido de uma forma muito particular, ou seja, seguir o raciocínio de cada pessoa. Portanto, apesar de colocarmos várias soluções aqui, você poderá criar sua própria versão da resolução e praticar.
#
# ---
#
# ## pré-requisito para resolver os exercícios
#
# Para resolver esses exercícios você precisará compreender no mínimo alguns conceitos da programação, são eles:
# - Como declarar variáveis
# - Como atribuir valores para variáveis
# - Como funcionam os tipos de dados de cada variável (inteiro, string, etc)
# - Como realizar o input de dados usando o teclado (input)
# - Como realizar a saída de dados usando o terminal (print)
# - O que são e como usar os conectores lógicos (and, or)
# - Compreender o que são e como usar condicionais (IF e Else)
#
# Caso você não conheça algum desses assuntos, pare um pouco e dê uma revisada no conteúdo antes de prosseguir.
#
# ---
#
# ## Quantos exercicios eu preciso resolver?
#
# Isso é muito pessoal, cada um possui seu nível de "saturação". Deixe-me explicar isso melhor...
#
# Ao resolver esses exercícios, chega um determinado momento que eles se tornam quase todos muito semelhantes. Isso é previsível já que estamos explorando apenas um recurso da linguagem que é a decisão.
#
# P: Então, preciso resolver todos os exercícios?
# R: Acredito que não... resolva os exercícios apenas até você mesmo se convencer que realmente compreendeu o assunto e que não há mais nada de novo sendo adicionado.

# %% [markdown]
# ---
#
# 1- Faça um programa que peça dois números e imprima o maior deles
# Dica: para realizar a inserção de dados pelo usuário utilize a função input("texto para o usuario")
#
#
# ---

# %%
numero_1 = int(input("Digite um número(0-10): "))
numero_2 = int(input("Digite um número(0-10): "))

if numero_1 > numero_2:
  resultado = numero_1
elif numero_1 == numero_2:
  resultado = "são iguais"
else:
  resultado = numero_2
print(f"Número maior: {resultado}")
# Out:
# Digite um número(0-10): 8
# Digite um número(0-10): 9
# Número maior: 9

# %%
numero_1 = int(input("Digite um número(0-10): "))
numero_2 = int(input("Digite um número(0-10): "))

if numero_1 > numero_2:
  resultado = numero_1
elif numero_1 == numero_2:
  resultado = "são iguais"
else:
  resultado = numero_2
print(f"Número maior: {resultado}")
# Out:
# Digite um número(0-10): 8
# Digite um número(0-10): 8
# Número maior: são iguais

# %%
numero_1 = int(input("Digite um número(0-10): "))
numero_2 = int(input("Digite um número(0-10): "))

if numero_1 > numero_2:
  resultado = numero_1
elif numero_1 == numero_2:
  resultado = "são iguais"
else:
  resultado = numero_2
print(f"Número maior: {resultado}")
# Out:
# Digite um número(0-10): 10
# Digite um número(0-10): 3
# Número maior: 10

# %% [markdown]
# 2- Faça um programa que peça um valor e mostre na tela se o valor é positivo ou
# negativo
#
#
#
# ---

# %%
valor = float(input("Digite um Número: "))

if valor >= 0:
  print("Positivo")
else:
  print("Negativo")
# Out:
# Digite um Número: 25
# Positivo

# %%
valor = float(input("Digite um Número: "))

if valor >= 0:
  print("Positivo")
else:
  print("Negativo")
# Out:
# Digite um Número: -6
# Negativo

# %% [markdown]
# 3- Faça um programa que verifique se uma letra digitada é “F” ou “M”. Conforme a letra escrever: F – Feminino, M- Masculino, Sexo inválido.

# %%
letra = input("Digite seu sexo, utilizando (F) ou (M): ")

if letra == "F":
  print("Feminino")
elif letra == "M":
  print("Masculino")
else:
  print("sexo inválido")
# Out:
# Digite seu sexo, utilizando (F) ou (M): F
# Feminino

# %%
letra = input("Digite seu sexo, utilizando (F) ou (M): ")

if letra == "F" or "f":
  print("Feminino")
elif letra == "M" or "f":
  print("Masculino")
else:
  print("sexo inválido")
# Out:
# Digite seu sexo, utilizando (F) ou (M): f
# Feminino

# %%
letra = input("Digite seu sexo, utilizando (F) ou (M): ")

if letra == "F":
  print("Feminino")
elif letra == "M":
  print("Masculino")
else:
  print("sexo inválido")
# Out:
# Digite seu sexo, utilizando (F) ou (M): S
# sexo inválido

# %% [markdown]
# 4- Faça um programa que verifique se uma letra digitada é vogal ou consoante.
#
#
# ---

# %%
letra = input("Digite uma letra do alfabeto (minúscula): ")

if letra == "a" or letra == "e" or letra == "i" or letra == "o" or letra == "u":
  print("Vogal")
else:
  print("Consoante")
# Out:
# Digite uma letra do alfabeto (minúscula): e
# Vogal

# %%
letra = input("Digite uma letra do alfabeto (minúscula): ")

if letra == "a" or letra == "e" or letra == "i" or letra == "o" or letra == "u":
  print("Vogal")
else:
  print("Consoante")
# Out:
# Digite uma letra do alfabeto (minúscula): m
# Consoante

# %% [markdown]
# 5- Faça um programa para a leitura de duas notas parciais de um aluno.
#  - A mensagem “Aprovado”, se a média alcançada for maior ou igual a sete;
#  - A mensagem “Aprovado com Distinção”, se a média for igual a dez;
#  - A mensagem “Reprovado” se a média for menor de do que sete;
#
#
#
# ---

# %%
nota_1 = float(input("Digite a nota 1: "))
nota_2 = float(input("Digite a nota 2: "))
media = (nota_1 + nota_2)/2

if media == 10:
  print("Aprovado com Distinção")
elif media >= 7:
  print("Aprovado")
else:
  print("Reprovado")
# Out:
# Digite a nota 1: 9
# Digite a nota 2: 8
# Aprovado

# %%
nota_1 = float(input("Digite a nota 1: "))
nota_2 = float(input("Digite a nota 2: "))
media = (nota_1 + nota_2)/2

if media == 10:
  print("Aprovado com Distinção")
elif media >= 7:
  print("Aprovado")
else:
  print("Reprovado")
# Out:
# Digite a nota 1: 5
# Digite a nota 2: 4
# Reprovado

# %%
nota_1 = float(input("Digite a nota 1: "))
nota_2 = float(input("Digite a nota 2: "))
media = (nota_1 + nota_2)/2

if media == 10:
  print("Aprovado com Distinção")
elif media >= 7:
  print("Aprovado")
else:
  print("Reprovado")
# Out:
# Digite a nota 1: 10
# Digite a nota 2: 10
# Aprovado com Distinção

# %% [markdown]
# 6- Faça um programa que leia três números e mostre o maior deles;
#
#
#
# ---

# %%
numero_1 = 4
numero_2 = 10
numero_3 = 15

if (numero_1 > numero_2) and (numero_1 > numero_3):
  print(numero_1)
elif (numero_2 > numero_1) and (numero_2 > numero_3):
  print(numero_2)
else:
  print(numero_3)
# Out:
# 15

# %% [markdown]
# 7- Faça um programa que leia três números e mostre o maior e o menor deles;
#
#
#
# ---

# %%
numero_1 = 4
numero_2 = 10
numero_3 = 15

if (numero_1 > numero_2) and (numero_1 > numero_3):
  print(f"Maior número: {numero_1}")
elif (numero_2 > numero_1) and (numero_2 > numero_3):
  print(f"Maior número: {numero_2}")
else:
  print(f"Maior número: {numero_3}")


if (numero_1 < numero_2) and (numero_1 < numero_3):
  print(f"Menor número: {numero_1}")
elif (numero_2 < numero_1) and (numero_2 < numero_3):
  print(f"Menor número: {numero_2}")
else:
  print(f"Menor número: {numero_3}")
# Out:
# Maior número: 15
# Menor número: 4

# %% [markdown]
# 8- Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre o mais barato.
#
#
#
# ---

# %%
produto_1 = float(input("Qual valor do produto 1: R$ "))
produto_2 = float(input("Qual o valor do produto 2: R$ "))
produto_3 = float(input("Qual o valor do produto 3: R$ "))

valor = 0

if produto_1 < produto_2 and produto_1 < produto_3:
  valor = produto_1
elif produto_2 < produto_1 and produto_2 < produto_3:
  valor = produto_2
else:
  valor = produto_3
print(f"O produto mais barato custa: R$ {valor}")
# Out:
# Qual valor do produto 1: R$ 1000000
# Qual o valor do produto 2: R$ 8952314
# Qual o valor do produto 3: R$ 4578
# O produto mais barato custa: R$ 4578.0

# %%
produto_1 = float(input("Qual valor do produto 1: R$ "))
produto_2 = float(input("Qual o valor do produto 2: R$ "))
produto_3 = float(input("Qual o valor do produto 3: R$ "))

valor = 0

if produto_1 < produto_2 and produto_1 < produto_3:
  valor = produto_1
elif produto_2 < produto_1 and produto_2 < produto_3:
  valor = produto_2
else:
  valor = produto_3
print(f"O produto mais barato custa: R$ {valor}")
# Out:
# Qual valor do produto 1: R$ -123
# Qual o valor do produto 2: R$ 859
# Qual o valor do produto 3: R$ 63.12
# O produto mais barato custa: R$ -123.0

# %% [markdown]
# 9- Faça um programa que leia três números e mostre-os em ordem decrescente.
#
#
#
# ---

# %%
numero_1 = 4
numero_2 = 10
numero_3 = 15

# Maior número:
maior_numero = 0
if (numero_1 > numero_2) and (numero_1 > numero_3):
  maior_numero = numero_1
elif (numero_2 > numero_1) and (numero_2 > numero_3):
  maior_numero = numero_2
else:
 maior_numero = numero_3

# Menor número:
menor_numero = 0
if (numero_1 < numero_2) and (numero_1 < numero_3):
  menor_numero = numero_1
elif (numero_2 < numero_1) and (numero_2 < numero_3):
  menor_numero = numero_2
else:
  menor_numero = numero_3

# Número do meio:
numero_meio = 0
if (numero_2 > numero_1 > numero_3) or (numero_3 > numero_1 > numero_2):
  numero_meio = numero_1
elif (numero_1 > numero_2 > numero_3) or (numero_3 > numero_2 > numero_1):
  numero_meio = numero_2
else:
  numero_meio = numero_3

print(f"Número em ordem decrescente: {maior_numero}, {numero_meio}, {menor_numero}")
# Out:
# Número em ordem decrescente: 15, 10, 4

# %% [markdown]
# 10- Faça um programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-vespertino ou N-noturno.
# Imprima a mensagem “Bom dia!” ou  “Boa Noite” ou “Valor inválido”, conforme o caso.
#
#
#
# ---

# %%
turno = input("Qual turno você estuda: ")

matutino = "m" or "M"
vespertino = "v" or "V"
noturno = "n" or "N"

if turno == matutino:
  print("Bom Dia!")
elif turno == noturno:
  print("Boa noite")
else:
  print("Valor inválido")
# Out:
# Qual turno você estuda: m
# Bom Dia!

# %%
turno = input("Qual turno você estuda: ")

matutino = "m" or "M"
vespertino = "v" or "V"
noturno = "n" or "N"

if turno == matutino:
  print("Bom Dia!")
elif turno == noturno:
  print("Boa noite")
else:
  print("Valor inválido")
# Out:
# Qual turno você estuda: n
# Boa noite

# %%
turno = input("Qual turno você estuda: ")

matutino = "m" or "M"
vespertino = "v" or "V"
noturno = "n" or "N"

if turno == matutino:
  print("Bom Dia!")
elif turno == noturno:
  print("Boa noite")
else:
  print("Valor inválido")
# Out:
# Qual turno você estuda: v
# Valor inválido

# %% [markdown]
#  11- As organizações CSM resolveram dar um aumento de salário aos seus
#  colaboradores e lhe contrataram para desenvolver o programa que calculará os reajustes.
#  - Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no salário atual;
#  - Salários até RS 280,00 (incluindo): aumento de 20%;
#  - Salários entre RS 280,00 e RS 700,00: aumento de 15%;
#  - Salários entre RS 700,00 e RS 1500,00: aumento de 10%;
#  - Salários de RS 1500,00 em diante: aumento de 5% Após o aumento ser realizado;
#
# Informe na tela os seguintes dados;
#  - O salário antes do reajuste;
#  - O percentual de aumento aplicado;
#  - O valor do aumento;
#  - O novo salário, após o aumento.
#
#
#
# ---

# %%
salario = float(input("Digite o salário: R$ "))
percentual = 0
aumento = 0
novo_salario = 0

if salario >=1500:
  percentual = "5%"
  aumento = salario * 0.05
  novo_salario = salario + aumento
elif salario >= 700 and salario < 1500:
  percentual = "10%"
  aumento = salario * 0.10
  novo_salario = salario + aumento
elif salario > 280 and salario < 700:
  percentual = "15%"
  aumento = salario * 0.15
  novo_salario = salario + aumento
else:
  percentual = "20%"
  aumento = salario * 0.20
  novo_salario = salario + aumento

print(f"O percentual de aumento: {percentual}, Valor do Aumento: R$ {aumento:.2f}, Novo salário: R$ {novo_salario:.2f}")
# Out:
# Digite o salário: R$ 528.14
# O percentual de aumento: 15%, Valor do Aumento: R$ 79.22, Novo salário: R$ 607.36

# %%
salario = float(input("Digite o salário: R$ "))
percentual = 0
aumento = 0
novo_salario = 0

if salario >=1500:
  percentual = "5%"
  aumento = salario * 0.05
  novo_salario = salario + aumento
elif salario >= 700 and salario < 1500:
  percentual = "10%"
  aumento = salario * 0.10
  novo_salario = salario + aumento
elif salario > 280 and salario < 700:
  percentual = "15%"
  aumento = salario * 0.15
  novo_salario = salario + aumento
else:
  percentual = "20%"
  aumento = salario * 0.20
  novo_salario = salario + aumento

print(f"O percentual de aumento: {percentual}, Valor do Aumento: R$ {aumento:.2f}, Novo salário: R$ {novo_salario:.2f}")
# Out:
# Digite o salário: R$ 150
# O percentual de aumento: 20%, Valor do Aumento: R$ 30.00, Novo salário: R$ 180.00

# %%
salario = float(input("Digite o salário: R$ "))
percentual = 0
aumento = 0
novo_salario = 0

if salario >=1500:
  percentual = "5%"
  aumento = salario * 0.05
  novo_salario = salario + aumento
elif salario >= 700 and salario < 1500:
  percentual = "10%"
  aumento = salario * 0.10
  novo_salario = salario + aumento
elif salario > 280 and salario < 700:
  percentual = "15%"
  aumento = salario * 0.15
  novo_salario = salario + aumento
else:
  percentual = "20%"
  aumento = salario * 0.20
  novo_salario = salario + aumento

print(f"O percentual de aumento: {percentual}, Valor do Aumento: R$ {aumento:.2f}, Novo salário: R$ {novo_salario:.2f}")
# Out:
# Digite o salário: R$ 1400
# O percentual de aumento: 10%, Valor do Aumento: R$ 140.00, Novo salário: R$ 1540.00

# %% [markdown]
#  12- Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do salário bruto, mas não é descontado (é a empresa que deposita.) O salário líquido corresponde ao salário bruto menos os descontos O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.
#  - Desconto do IR;
#  - Salário Bruto ate RS900,00 (inclusive) – Isento;
#  - Salário Bruto de RS 1500, 00 (inclusive) – desconto de 5%;
#  - Salario bruto até RS 2500,00 (Inclusive) – desconto de 10%;
#  - Salário bruto acima de 2500 – Desconto de 20%.
#
# Imprima na tela as informações, dispostas conforme o exemplo abaixo, no exemplo valor da hora é 5 e a quantidade de horas é 220.
#
# ```plaintext
# Salário bruto (5 * 220)            : RS   1100,00
#  ( - ) IR (5%)                     : RS     55,00
#  ( - ) INSS ( 10% )                : RS    110,00
#  FGTS ( 11%)                       : RS    121,00
#  Total de descontos                : RS    165,00
# Salário Líquido                    : RS    935,00
# ```
#
#
#
# ---

# %%
print("****Folha de Pagamento****")
horas = int(input("Digite o número de horas trabalhadas: "))
valor = float(input("Digite o valor da hora trabalhada: R$ "))
salario_bruto = horas * valor
ir = 0
inss = 0
fgts = 0
sindicato = 0
percentual = 0

if salario_bruto > 2500:
  percentual = "20%"
  ir = salario_bruto * 0.20
  inss = salario_bruto * 0.10
  fgts = salario_bruto * 0.11
  sindicato = salario_bruto * 0.03
elif salario_bruto > 1500 and salario_bruto <= 2500:
  percentual = "10%"
  ir = salario_bruto * 0.10
  inss = salario_bruto * 0.10
  fgts = salario_bruto * 0.11
  sindicato = salario_bruto * 0.03
elif salario_bruto > 900 and salario_bruto <= 1500:
  percentual = "5%"
  ir = salario_bruto * 0.05
  inss = salario_bruto * 0.10
  fgts = salario_bruto * 0.11
  sindicato = salario_bruto * 0.03
else:
  percentual = "0%"
  ir = salario_bruto * 0
  inss = salario_bruto * 0.10
  fgts = salario_bruto * 0.11
  sindicato = salario_bruto * 0.03

total_desconto = ir + inss + sindicato
salario_liquido = salario_bruto - total_desconto

print(f"Salario Bruto ({horas} * {valor}): R$ {salario_bruto:.2f}")
print(f"( - ) IR ({percentual})          : R$ {ir:.2f}")
print(f"( - ) INSS (10%)                 : R$ {inss:.2f}")
print(f"Sindicato (3%)                   : R$ {sindicato:.2f}")
print(f"FGTS (11%)                       : R$ {fgts:.2f}")
print(f"Total de Desconto                : R$ {total_desconto:.2f}")
print(f"Salário Líquido                  : R$ {salario_liquido:.2f}")
# Out:
# ****Folha de Pagamento****
# Digite o número de horas trabalhadas: 110
# Digite o valor da hora trabalhada: R$ 35
# Salario Bruto (110.0 * 35.0): R$ 3850.00
# ( - ) IR (20%)          : R$ 770.00
# ( - ) INSS (10%)                 : R$ 385.00
# Sindicato (3%)                   : R$ 115.50
# FGTS (11%)                       : R$ 423.50
# Total de Desconto                : R$ 1270.50
# Salário Líquido                  : R$ 2579.50

# %% [markdown]
# 13 – Faça um Programa que leia um número e exiba o dia correspondente da semana.
#  (1- Domingo , 2- Segunda, etc.) se digitar outro valor deve aparecer “valor inválido)
#
#  ---

# %%
numero = int(input("Digite o número correspondente ao dia da semana: "))

if numero == 1:
  print("Domingo")
elif numero == 2:
  print("Segunda")
elif numero == 3:
  print("Terça")
elif numero == 4:
  print("Quarta")
elif numero == 5:
  print("Quinta")
elif numero == 6:
  print("Sexta")
elif numero == 7:
  print("Sábado")
else:
  print("Valor inválido")
# Out:
# Digite o número correspondente ao dia da semana: 2
# Segunda

# %%
numero = float(input("Digite o número correspondente ao dia da semana: "))

if numero == 1:
  print("Domingo")
elif numero == 2:
  print("Segunda")
elif numero == 3:
  print("Terça")
elif numero == 4:
  print("Quarta")
elif numero == 5:
  print("Quinta")
elif numero == 6:
  print("Sexta")
elif numero == 7:
  print("Sábado")
else:
  print("Valor inválido")
# Out:
# Digite o número correspondente ao dia da semana: 5.2
# Valor inválido

# %% [markdown]
#  14 – Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre,
#  e calcule a sua média. A atribuição de conceitos obedece à tabela abaixo:
#
# ```plaintext
#  Média de aproveitamento                  Conceito
#  Entre 9.0 e 10.0                            A
#  Entre 7.5 e 9.0                             B
#  Entre 6.0 e 7.5                             C
#  Entre 4.0 e 6.0                             D
#  Entre 4.0 e zero                            E
# ```
#
# O algoritmo deve mostrar na tela as notas, a média, o conceito correspondente e a mensagem “APROVADO” se o
#  conceito for A, B ou C “REPROVADO” se o conceito for D ou E.
#
#  ---

# %%
nota_1 = float(input("Digite a Nota 1: "))
if nota_1 < 0 or nota_1 > 10:
  print("nota inválida")
nota_2 = float(input("Digite a Nota 2: "))
if nota_2 < 0 or nota_2 > 10:
  print("nota inválida")
media = (nota_1 + nota_2) // 2

if media >= 9:
  print(f"Conceito A - APROVADO")
elif media >= 7.5 and media < 9:
  print(f"Conceito B - APROVADO")
elif media >= 6 and media < 7.5:
  print(f"Conceito C - APROVADO")
elif media >= 4 and media < 6:
  print(f"Conceito D - REPROVADO")
else:
  print("Conceito E - REPROVADO")
# Out:
# Digite a Nota 1: 8
# Digite a Nota 2: 6.7
# Conceito C - APROVADO

# %% [markdown]
#  15- Faça um programa que peça os 3 lados de um triângulo. O programa deverá informar se os valores podem ser um triângulo. Indique, caso os lados formem um triângulo, se o mesmo é: equilátero, isósceles ou escaleno.
#
#  Dicas:
#  - Três lados formam um triangulo quando a soma de quaisquer dos  dois lados é menor que o terceiro.
#  - Triângulo Equilátero: três lados iguais;
#  - Triângulo isósceles: quaisquer dois lados iguais;
#  - Triângulo Escaleno: três lados diferentes;
#
#  ---

# %%
lado_a = float(input("Digite o valor do lado A: "))
if lado_a <= 0:
  print("valor inválido")
lado_b = float(input("Digite o valor do lado B: "))
if lado_b <= 0:
  print("valor inválido")
lado_c = float(input("Digite o valor do lado C: "))
if lado_c <= 0:
  print("valor inválido")

if lado_a < (lado_b + lado_c) or lado_b < (lado_a + lado_c) or lado_c < (lado_a + lado_b):
  print("Pode ser um triângulo")
else:
  print("Não pode ser um triângulo")

if lado_a == lado_b == lado_c:
  print("Triângulo Equilátero")
elif lado_a != lado_b != lado_c:
  print("Triângulo Escaleno")
else:
  print("Triângulo Isósceles")
# Out:
# Digite o valor do lado A: 8
# Digite o valor do lado B: 6
# Digite o valor do lado C: 7
# Pode ser um triângulo
# Triângulo Escaleno

# %% [markdown]
# 16- Faça um programa que calcule as raízes de uma equação do segundo grau, na forma
#
# ax2 + bx + c.
#
# O programa deverá pedir os valores de a, b e c e fazer as consistências, informando ao usuário nas seguintes situações:
#
#  - Se o usuário informar o valor de A igual a zero. a equação não e do segundo grau e o programa não deve fazer
#  pedir os demais valores, sendo encerrado;
#  - Se o delta calculado for negativo, a equação não possui raízes reais. Informe ao usuário e encerre o programa;
#  - Se o delta calculado for igual a zero a equação possui apenas uma raiz real; informe ao usuário;
#  - Se o delta for positivo, a equação possui duas raízes reais; informe-as ao usuário;
#
# ---

# %% [markdown]
# 17- Faça um Programa que peça um número correspondente a um determinado ano e em seguida informe se este ano e ou não bissexto.
#
# [Acesse aqui mais informações sobre ano bissexto](https://escolakids.uol.com.br/matematica/calculo-do-ano-bissexto.htm)
#
# ---

# %% [markdown]
# 18- Faça um Programa que peça um número inteiro e determine se ele e par ou ímpar.
# Dica: utilize o operador módulo (resto da divisão).
#
# ---

# %% [markdown]
# 19- Faça um Programa que leia 1 número e em seguida pergunte ao usuário qual operação ele deseja realizar. O resultado da operação deve ser acompanhado de uma frase que diga se o número e:
# - Par ou ímpar;
# - Positivo ou negativo;
#
# ---

# %% [markdown]
#  20- Faça um programa que faça 5 perguntas para uma pessoa sobre um crime. As perguntas são:
#  - "Telefonou para a vítima?"
#  - "Esteve no local do crime?"
#  - "Mora perto da vítima?"
#  - "Devia para a vítima?"
#  - "Já trabalhou com a vítima?"
#
# O programa deve no final emitir uma classificação sobre a participação da pessoa no crime.
# Se a pessoa responder positivamente a 2 questões ela deve ser classificada como "Suspeita",
# entre 3 e 4 como "Cúmplice" e 5 como “Assassino“. Caso contrário, ele será classificado como "Inocente“.
#
#
# ---

# %% [markdown]
# 21- Faça um programa que peça dois números ao usuário e mostre qual o maior e qual o menor
#
# ---

# %% [markdown]
# 22- Faça um programa que receba três inteiros e diga qual deles é o maior e qual o menor.
#
# DESAFIO: você consegue criar mais de uma solução?
#
# ---

# %% [markdown]
# 23- Escreva um programa em C que recebe um inteiro e diga se é par ou ímpar.
#
# Dica: Use o operador matemático % (resto da divisão ou módulo) e o teste condicional if.
#
# ---

# %% [markdown]
# 24- Escreva um programa que pergunte o raio de uma circunferência, e sem seguida mostre o diâmetro, comprimento e área da circunferência
#
# ---

# %% [markdown]
# 25- Para doar sangue é necessário ter entre 18 e 67 anos. Faça um aplicativo que pergunte a idade de uma pessoa e diga se ela pode doar sangue ou não. Use alguns dos operadores lógicos OU (||) e E (&&).
#
# ---

# %% [markdown]
# 26- Escreva um programa que pergunte o dia, mês e ano do aniversário de uma pessoa e diga se a data é
# válida ou não. Caso não seja, diga o motivo. Suponha que todos os meses tem 31 dias e que estejamos no ano de 2013.
#
# ---

# %% [markdown]
# 27- Crie um programa que peça um número ao usuário e armazene ele na variável x. Depois peça outro número e armazene na variável y. Mostre esses números. Em seguida, faça com que x passe a ter o valor de y, e que y passe a ter o valor de x.
#
# ---
